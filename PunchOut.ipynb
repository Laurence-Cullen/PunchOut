# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    images = np.array(data['filenames'])
    images_targets = np_utils.to_categorical(np.array(data['target']), 2) # [1,0] is no_punch, [0,1] is right_punch
    return images, images_targets

#load training dataset
train_images, train_targets = load_dataset('Images/train') 
test_images, test_targets = load_dataset('Images/test')

print('There are %s total training images.\n' % len(train_images))
print('There are %s total testing images.\n' % len(test_images))
# Out:
# Using TensorFlow backend.
# There are 646 total training images.
#
# There are 76 total testing images.

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_images).astype('float32')/255
test_tensors = paths_to_tensor(test_images).astype('float32')/255
# Out:
# 100%|██████████| 646/646 [00:40<00:00, 16.71it/s]
# 100%|██████████| 76/76 [00:04<00:00, 15.74it/s]

# %%
from sklearn.model_selection import train_test_split

train_tensors, valid_tensors, train_targets, valid_targets = train_test_split(train_tensors, train_targets, 
                                                                             test_size=0.2, 
                                                                             random_state=42)

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint  
from keras.callbacks import EarlyStopping
from keras import optimizers
from keras.layers import BatchNormalization
from keras.regularizers import l1, l2
from keras.layers import GaussianNoise
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator

epochs = 1000
patience = 20
optimizer= 'rmsprop'

# %%
def model_compile_fit(model):
    
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    print("Optimizer:", optimizer)
    print("Patience:", patience)
    
    checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)
    
    early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=patience, verbose=0, mode='auto', 
          baseline=None, restore_best_weights=False)
    
    model.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer,
          early_stopping], verbose=2)
    
    model.load_weights('saved_models/weights.best.from_scratch.hdf5')
    
    # get index of predicted action for each image in test set
    action_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

    # report test accuracy
    test_accuracy = 100*np.sum(np.array(action_predictions)==np.argmax(test_targets, axis=1))/len(2) #len(2) is len(diff actions)
    print('Test accuracy: %.4f%%' % test_accuracy)

# %%
model = Sequential()
model.add(Conv2D(input_shape=(224,224,3), filters=16, kernel_size=(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(input_shape=train_tensors.shape, filters=32, kernel_size=(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(input_shape=train_tensors.shape, filters=64, kernel_size=(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(GlobalAveragePooling2D())
model.add(Dense(2, activation = 'softmax'))

model.summary()

model_compile_fit(model)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 224, 224, 16)      448
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 112, 112, 32)      4640
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 56, 56, 64)        18496
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 23,714
# Trainable params: 23,714
# Non-trainable params: 0
# _________________________________________________________________
# Optimizer: rmsprop
# Patience: 10
# Train on 516 samples, validate on 130 samples
# Epoch 1/1000
#  - 3s - loss: 0.6929 - acc: 0.5659 - val_loss: 0.6828 - val_acc: 0.5769
#
# Epoch 00001: val_loss improved from inf to 0.68283, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 2/1000
#  - 1s - loss: 0.6871 - acc: 0.5562 - val_loss: 0.6789 - val_acc: 0.5769
#
# Epoch 00002: val_loss improved from 0.68283 to 0.67885, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 3/1000
#  - 1s - loss: 0.6831 - acc: 0.5698 - val_loss: 0.6764 - val_acc: 0.5769
#
# Epoch 00003: val_loss improved from 0.67885 to 0.67645, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 4/1000
#  - 1s - loss: 0.6852 - acc: 0.5504 - val_loss: 0.6725 - val_acc: 0.5769
#
# Epoch 00004: val_loss improved from 0.67645 to 0.67246, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 5/1000
#  - 1s - loss: 0.6811 - acc: 0.5484 - val_loss: 0.6689 - val_acc: 0.5769
#
# Epoch 00005: val_loss improved from 0.67246 to 0.66891, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 6/1000
#  - 1s - loss: 0.6779 - acc: 0.5756 - val_loss: 0.6756 - val_acc: 0.6231
#
# Epoch 00006: val_loss did not improve from 0.66891
# Epoch 7/1000
#  - 1s - loss: 0.6732 - acc: 0.5814 - val_loss: 0.6740 - val_acc: 0.5462
#
# Epoch 00007: val_loss did not improve from 0.66891
# Epoch 8/1000
#  - 1s - loss: 0.6706 - acc: 0.5736 - val_loss: 0.6551 - val_acc: 0.5769
#
# Epoch 00008: val_loss improved from 0.66891 to 0.65506, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 9/1000
#  - 1s - loss: 0.6675 - acc: 0.5736 - val_loss: 0.6623 - val_acc: 0.6538
#
# Epoch 00009: val_loss did not improve from 0.65506
# Epoch 10/1000
#  - 1s - loss: 0.6650 - acc: 0.6202 - val_loss: 0.6378 - val_acc: 0.6385
#
# Epoch 00010: val_loss improved from 0.65506 to 0.63775, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 11/1000
#  - 1s - loss: 0.6612 - acc: 0.6047 - val_loss: 0.6408 - val_acc: 0.6615
#
# Epoch 00011: val_loss did not improve from 0.63775
# Epoch 12/1000
#  - 1s - loss: 0.6542 - acc: 0.6027 - val_loss: 0.6533 - val_acc: 0.5769
#
# Epoch 00012: val_loss did not improve from 0.63775
# Epoch 13/1000
#  - 1s - loss: 0.6580 - acc: 0.6221 - val_loss: 0.6448 - val_acc: 0.6077
#
# Epoch 00013: val_loss did not improve from 0.63775
# Epoch 14/1000
#  - 1s - loss: 0.6493 - acc: 0.6085 - val_loss: 0.6844 - val_acc: 0.5308
#
# Epoch 00014: val_loss did not improve from 0.63775
# Epoch 15/1000
#  - 1s - loss: 0.6483 - acc: 0.5950 - val_loss: 0.6236 - val_acc: 0.6154
#
# Epoch 00015: val_loss improved from 0.63775 to 0.62363, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 16/1000
#  - 1s - loss: 0.6407 - acc: 0.6221 - val_loss: 0.6316 - val_acc: 0.5846
#
# Epoch 00016: val_loss did not improve from 0.62363
# Epoch 17/1000
#  - 1s - loss: 0.6329 - acc: 0.6395 - val_loss: 0.6555 - val_acc: 0.5846
#
# Epoch 00017: val_loss did not improve from 0.62363
# Epoch 18/1000
#  - 1s - loss: 0.6314 - acc: 0.6453 - val_loss: 0.6234 - val_acc: 0.6692
#
# Epoch 00018: val_loss improved from 0.62363 to 0.62335, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 19/1000
#  - 1s - loss: 0.6354 - acc: 0.6473 - val_loss: 0.5981 - val_acc: 0.6769
#
# Epoch 00019: val_loss improved from 0.62335 to 0.59813, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 20/1000
#  - 1s - loss: 0.6274 - acc: 0.6531 - val_loss: 0.5992 - val_acc: 0.7000
#
# Epoch 00020: val_loss did not improve from 0.59813
# Epoch 21/1000
#  - 1s - loss: 0.6192 - acc: 0.6744 - val_loss: 0.6231 - val_acc: 0.6154
#
# Epoch 00021: val_loss did not improve from 0.59813
# Epoch 22/1000
#  - 1s - loss: 0.6184 - acc: 0.6628 - val_loss: 0.5842 - val_acc: 0.7154
#
# Epoch 00022: val_loss improved from 0.59813 to 0.58419, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 23/1000
#  - 1s - loss: 0.6129 - acc: 0.6802 - val_loss: 0.5985 - val_acc: 0.6538
#
# Epoch 00023: val_loss did not improve from 0.58419
# Epoch 24/1000
#  - 1s - loss: 0.6178 - acc: 0.6609 - val_loss: 0.5922 - val_acc: 0.7154
#
# Epoch 00024: val_loss did not improve from 0.58419
# Epoch 25/1000
#  - 1s - loss: 0.6003 - acc: 0.6783 - val_loss: 0.5862 - val_acc: 0.6692
#
# Epoch 00025: val_loss did not improve from 0.58419
# Epoch 26/1000
#  - 1s - loss: 0.6147 - acc: 0.6686 - val_loss: 0.5669 - val_acc: 0.7308
#
# Epoch 00026: val_loss improved from 0.58419 to 0.56689, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 27/1000
#  - 1s - loss: 0.6031 - acc: 0.6667 - val_loss: 0.5636 - val_acc: 0.7385
#
# Epoch 00027: val_loss improved from 0.56689 to 0.56357, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 28/1000
#  - 1s - loss: 0.6091 - acc: 0.6686 - val_loss: 0.5595 - val_acc: 0.7615
#
# Epoch 00028: val_loss improved from 0.56357 to 0.55946, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 29/1000
#  - 1s - loss: 0.6026 - acc: 0.6705 - val_loss: 0.6421 - val_acc: 0.5308
#
# Epoch 00029: val_loss did not improve from 0.55946
# Epoch 30/1000
#  - 1s - loss: 0.6060 - acc: 0.6764 - val_loss: 0.5737 - val_acc: 0.6769
#
# Epoch 00030: val_loss did not improve from 0.55946
# Epoch 31/1000
#  - 1s - loss: 0.5946 - acc: 0.7016 - val_loss: 0.5462 - val_acc: 0.7615
#
# Epoch 00031: val_loss improved from 0.55946 to 0.54622, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 32/1000
#  - 1s - loss: 0.5965 - acc: 0.6899 - val_loss: 0.5838 - val_acc: 0.6692
#
# Epoch 00032: val_loss did not improve from 0.54622
# Epoch 33/1000
#  - 1s - loss: 0.5856 - acc: 0.6802 - val_loss: 0.5429 - val_acc: 0.7615
#
# Epoch 00033: val_loss improved from 0.54622 to 0.54291, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 34/1000
#  - 1s - loss: 0.6030 - acc: 0.6744 - val_loss: 0.5549 - val_acc: 0.7769
#
# Epoch 00034: val_loss did not improve from 0.54291
# Epoch 35/1000
#  - 1s - loss: 0.5778 - acc: 0.7016 - val_loss: 0.5470 - val_acc: 0.7538
#
# Epoch 00035: val_loss did not improve from 0.54291
# Epoch 36/1000
#  - 1s - loss: 0.5862 - acc: 0.6957 - val_loss: 0.5374 - val_acc: 0.7077
#
# Epoch 00036: val_loss improved from 0.54291 to 0.53743, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 37/1000
#  - 1s - loss: 0.5802 - acc: 0.7267 - val_loss: 0.5324 - val_acc: 0.7462
#
# Epoch 00037: val_loss improved from 0.53743 to 0.53243, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 38/1000
#  - 1s - loss: 0.5813 - acc: 0.6725 - val_loss: 0.5517 - val_acc: 0.7154
#
# Epoch 00038: val_loss did not improve from 0.53243
# Epoch 39/1000
#  - 1s - loss: 0.5792 - acc: 0.6899 - val_loss: 0.5606 - val_acc: 0.7231
#
# Epoch 00039: val_loss did not improve from 0.53243
# Epoch 40/1000
#  - 1s - loss: 0.5661 - acc: 0.7112 - val_loss: 0.5888 - val_acc: 0.6846
#
# Epoch 00040: val_loss did not improve from 0.53243
# Epoch 41/1000
#  - 1s - loss: 0.5851 - acc: 0.6802 - val_loss: 0.5282 - val_acc: 0.7385
# Epoch 00041: val_loss improved from 0.53243 to 0.52825, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 42/1000
#  - 1s - loss: 0.5741 - acc: 0.7287 - val_loss: 0.5128 - val_acc: 0.7769
#
# Epoch 00042: val_loss improved from 0.52825 to 0.51281, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 43/1000
#  - 1s - loss: 0.5753 - acc: 0.6880 - val_loss: 0.5204 - val_acc: 0.8000
#
# Epoch 00043: val_loss did not improve from 0.51281
# Epoch 44/1000
#  - 1s - loss: 0.5697 - acc: 0.7093 - val_loss: 0.4997 - val_acc: 0.7769
#
# Epoch 00044: val_loss improved from 0.51281 to 0.49969, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 45/1000
#  - 1s - loss: 0.5625 - acc: 0.7248 - val_loss: 0.4914 - val_acc: 0.7846
#
# Epoch 00045: val_loss improved from 0.49969 to 0.49144, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 46/1000
#  - 1s - loss: 0.5678 - acc: 0.6996 - val_loss: 0.4931 - val_acc: 0.7769
#
# Epoch 00046: val_loss did not improve from 0.49144
# Epoch 47/1000
#  - 1s - loss: 0.5615 - acc: 0.7267 - val_loss: 0.5491 - val_acc: 0.7231
#
# Epoch 00047: val_loss did not improve from 0.49144
# Epoch 48/1000
#  - 1s - loss: 0.5539 - acc: 0.7403 - val_loss: 0.5580 - val_acc: 0.7231
#
# Epoch 00048: val_loss did not improve from 0.49144
# Epoch 49/1000
#  - 1s - loss: 0.5739 - acc: 0.6996 - val_loss: 0.5394 - val_acc: 0.7385
#
# Epoch 00049: val_loss did not improve from 0.49144
# Epoch 50/1000
#  - 1s - loss: 0.5499 - acc: 0.7384 - val_loss: 0.5411 - val_acc: 0.7308
#
# Epoch 00050: val_loss did not improve from 0.49144
# Epoch 51/1000
#  - 1s - loss: 0.5616 - acc: 0.7248 - val_loss: 0.4936 - val_acc: 0.7462
#
# Epoch 00051: val_loss did not improve from 0.49144
# Epoch 52/1000
#  - 1s - loss: 0.5484 - acc: 0.7267 - val_loss: 0.5184 - val_acc: 0.6846
#
# Epoch 00052: val_loss did not improve from 0.49144
# Epoch 53/1000
#  - 1s - loss: 0.5535 - acc: 0.7132 - val_loss: 0.5222 - val_acc: 0.7462
#
# Epoch 00053: val_loss did not improve from 0.49144
# Epoch 54/1000
#  - 1s - loss: 0.5367 - acc: 0.7403 - val_loss: 0.5044 - val_acc: 0.7462
#
# Epoch 00054: val_loss did not improve from 0.49144
# Epoch 55/1000
#  - 1s - loss: 0.5590 - acc: 0.7093 - val_loss: 0.4904 - val_acc: 0.7846
#
# Epoch 00055: val_loss improved from 0.49144 to 0.49040, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 56/1000
#  - 1s - loss: 0.5304 - acc: 0.7267 - val_loss: 0.5455 - val_acc: 0.7077
#
# Epoch 00056: val_loss did not improve from 0.49040
# Epoch 57/1000
#  - 1s - loss: 0.5347 - acc: 0.7345 - val_loss: 0.4957 - val_acc: 0.6846
#
# Epoch 00057: val_loss did not improve from 0.49040
# Epoch 58/1000
#  - 1s - loss: 0.5413 - acc: 0.7112 - val_loss: 0.4528 - val_acc: 0.8077
#
# Epoch 00058: val_loss improved from 0.49040 to 0.45283, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 59/1000
#  - 1s - loss: 0.5354 - acc: 0.7306 - val_loss: 0.5793 - val_acc: 0.6462
#
# Epoch 00059: val_loss did not improve from 0.45283
# Epoch 60/1000
#  - 1s - loss: 0.5277 - acc: 0.7364 - val_loss: 0.5614 - val_acc: 0.6923
#
# Epoch 00060: val_loss did not improve from 0.45283
# Epoch 61/1000
#  - 1s - loss: 0.5299 - acc: 0.7578 - val_loss: 0.4536 - val_acc: 0.8385
#
# Epoch 00061: val_loss did not improve from 0.45283
# Epoch 62/1000
#  - 1s - loss: 0.5418 - acc: 0.7093 - val_loss: 0.4524 - val_acc: 0.8000
#
# Epoch 00062: val_loss improved from 0.45283 to 0.45236, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 63/1000
#  - 1s - loss: 0.5266 - acc: 0.7422 - val_loss: 0.5176 - val_acc: 0.7769
#
# Epoch 00063: val_loss did not improve from 0.45236
# Epoch 64/1000
#  - 1s - loss: 0.5317 - acc: 0.7442 - val_loss: 0.5015 - val_acc: 0.7538
#
# Epoch 00064: val_loss did not improve from 0.45236
# Epoch 65/1000
#  - 1s - loss: 0.5422 - acc: 0.7500 - val_loss: 0.4591 - val_acc: 0.8154
#
# Epoch 00065: val_loss did not improve from 0.45236
# Epoch 66/1000
#  - 1s - loss: 0.5184 - acc: 0.7616 - val_loss: 0.5213 - val_acc: 0.7769
#
# Epoch 00066: val_loss did not improve from 0.45236
# Epoch 67/1000
#  - 1s - loss: 0.5313 - acc: 0.7306 - val_loss: 0.4691 - val_acc: 0.7692
#
# Epoch 00067: val_loss did not improve from 0.45236
# Epoch 68/1000
#  - 1s - loss: 0.5243 - acc: 0.7519 - val_loss: 0.4472 - val_acc: 0.8154
#
# Epoch 00068: val_loss improved from 0.45236 to 0.44715, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 69/1000
#  - 1s - loss: 0.5168 - acc: 0.7287 - val_loss: 0.4438 - val_acc: 0.8000
#
# Epoch 00069: val_loss improved from 0.44715 to 0.44378, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 70/1000
#  - 1s - loss: 0.5014 - acc: 0.7733 - val_loss: 0.4735 - val_acc: 0.7846
#
# Epoch 00070: val_loss did not improve from 0.44378
# Epoch 71/1000
#  - 1s - loss: 0.5067 - acc: 0.7616 - val_loss: 0.4545 - val_acc: 0.7923
#
# Epoch 00071: val_loss did not improve from 0.44378
# Epoch 72/1000
#  - 1s - loss: 0.5000 - acc: 0.7422 - val_loss: 0.5471 - val_acc: 0.6692
#
# Epoch 00072: val_loss did not improve from 0.44378
# Epoch 73/1000
#  - 1s - loss: 0.4820 - acc: 0.7791 - val_loss: 0.7230 - val_acc: 0.6231
#
# Epoch 00073: val_loss did not improve from 0.44378
# Epoch 74/1000
#  - 1s - loss: 0.5129 - acc: 0.7364 - val_loss: 0.4647 - val_acc: 0.8000
#
# Epoch 00074: val_loss did not improve from 0.44378
# Epoch 75/1000
#  - 1s - loss: 0.4943 - acc: 0.7500 - val_loss: 0.4201 - val_acc: 0.8154
#
# Epoch 00075: val_loss improved from 0.44378 to 0.42009, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 76/1000
#  - 1s - loss: 0.5141 - acc: 0.7636 - val_loss: 0.4031 - val_acc: 0.8385
#
# Epoch 00076: val_loss improved from 0.42009 to 0.40306, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 77/1000
#  - 1s - loss: 0.5035 - acc: 0.7422 - val_loss: 0.4302 - val_acc: 0.8462
#
# Epoch 00077: val_loss did not improve from 0.40306
# Epoch 78/1000
#  - 1s - loss: 0.4987 - acc: 0.7694 - val_loss: 0.5180 - val_acc: 0.7462
#
# Epoch 00078: val_loss did not improve from 0.40306
# Epoch 79/1000
#  - 1s - loss: 0.4901 - acc: 0.7674 - val_loss: 0.4079 - val_acc: 0.8462
#
# Epoch 00079: val_loss did not improve from 0.40306
# Epoch 80/1000
#  - 1s - loss: 0.4792 - acc: 0.7539 - val_loss: 0.4136 - val_acc: 0.8077
#
# Epoch 00080: val_loss did not improve from 0.40306
# Epoch 81/1000
#  - 1s - loss: 0.4742 - acc: 0.7752 - val_loss: 0.3966 - val_acc: 0.8154
#
# Epoch 00081: val_loss improved from 0.40306 to 0.39657, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 82/1000
#  - 1s - loss: 0.4896 - acc: 0.7422 - val_loss: 0.6474 - val_acc: 0.6692
#
# Epoch 00082: val_loss did not improve from 0.39657
# Epoch 83/1000
#  - 1s - loss: 0.4889 - acc: 0.7674 - val_loss: 0.4087 - val_acc: 0.8385
#
# Epoch 00083: val_loss did not improve from 0.39657
# Epoch 84/1000
#  - 1s - loss: 0.4585 - acc: 0.7733 - val_loss: 0.5662 - val_acc: 0.6692
#
# Epoch 00084: val_loss did not improve from 0.39657
# Epoch 85/1000
#  - 1s - loss: 0.4806 - acc: 0.7616 - val_loss: 0.4304 - val_acc: 0.7846
#
# Epoch 00085: val_loss did not improve from 0.39657
# Epoch 86/1000
#  - 1s - loss: 0.4579 - acc: 0.7733 - val_loss: 0.5959 - val_acc: 0.6462
#
# Epoch 00086: val_loss did not improve from 0.39657
# Epoch 87/1000
#  - 1s - loss: 0.5028 - acc: 0.7519 - val_loss: 0.3980 - val_acc: 0.8385
#
# Epoch 00087: val_loss did not improve from 0.39657
# Epoch 88/1000
#  - 1s - loss: 0.4809 - acc: 0.7674 - val_loss: 0.4096 - val_acc: 0.8308
#
# Epoch 00088: val_loss did not improve from 0.39657
# Epoch 89/1000
#  - 1s - loss: 0.4540 - acc: 0.8023 - val_loss: 0.4267 - val_acc: 0.8308
#
# Epoch 00089: val_loss did not improve from 0.39657
# Epoch 90/1000
#  - 1s - loss: 0.4507 - acc: 0.7888 - val_loss: 0.4406 - val_acc: 0.7692
#
# Epoch 00090: val_loss did not improve from 0.39657
# Epoch 91/1000
#  - 1s - loss: 0.5041 - acc: 0.7597 - val_loss: 0.3788 - val_acc: 0.8538
#
# Epoch 00091: val_loss improved from 0.39657 to 0.37884, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 92/1000
#  - 1s - loss: 0.4508 - acc: 0.7849 - val_loss: 0.3811 - val_acc: 0.8462
#
# Epoch 00092: val_loss did not improve from 0.37884
# Epoch 93/1000
#  - 1s - loss: 0.4662 - acc: 0.7907 - val_loss: 0.3799 - val_acc: 0.8231
#
# Epoch 00093: val_loss did not improve from 0.37884
# Epoch 94/1000
#  - 1s - loss: 0.4463 - acc: 0.7849 - val_loss: 0.4185 - val_acc: 0.8308
#
# Epoch 00094: val_loss did not improve from 0.37884
# Epoch 95/1000
#  - 1s - loss: 0.4758 - acc: 0.7655 - val_loss: 0.3879 - val_acc: 0.8462
#
# Epoch 00095: val_loss did not improve from 0.37884
# Epoch 96/1000
#  - 1s - loss: 0.4633 - acc: 0.7713 - val_loss: 0.3833 - val_acc: 0.8231
#
# Epoch 00096: val_loss did not improve from 0.37884
# Epoch 97/1000
#  - 1s - loss: 0.4687 - acc: 0.7752 - val_loss: 0.3652 - val_acc: 0.8615
#
# Epoch 00097: val_loss improved from 0.37884 to 0.36523, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 98/1000
#  - 1s - loss: 0.4297 - acc: 0.7946 - val_loss: 0.3602 - val_acc: 0.8385
#
# Epoch 00098: val_loss improved from 0.36523 to 0.36020, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 99/1000
#  - 1s - loss: 0.4314 - acc: 0.8120 - val_loss: 0.6629 - val_acc: 0.6385
#
# Epoch 00099: val_loss did not improve from 0.36020
# Epoch 100/1000
#  - 1s - loss: 0.4751 - acc: 0.7655 - val_loss: 0.3556 - val_acc: 0.8308
#
# Epoch 00100: val_loss improved from 0.36020 to 0.35559, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 101/1000
#  - 1s - loss: 0.4527 - acc: 0.7733 - val_loss: 0.4475 - val_acc: 0.7769
#
# Epoch 00101: val_loss did not improve from 0.35559
# Epoch 102/1000
#  - 1s - loss: 0.4547 - acc: 0.8023 - val_loss: 0.4625 - val_acc: 0.7846
#
# Epoch 00102: val_loss did not improve from 0.35559
# Epoch 103/1000
#  - 1s - loss: 0.4479 - acc: 0.7849 - val_loss: 0.3510 - val_acc: 0.8692
#
# Epoch 00103: val_loss improved from 0.35559 to 0.35104, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 104/1000
#  - 1s - loss: 0.4155 - acc: 0.8101 - val_loss: 0.3708 - val_acc: 0.8308
#
# Epoch 00104: val_loss did not improve from 0.35104
# Epoch 105/1000
#  - 1s - loss: 0.4580 - acc: 0.7733 - val_loss: 0.3632 - val_acc: 0.8308
#
# Epoch 00105: val_loss did not improve from 0.35104
# Epoch 106/1000
#  - 1s - loss: 0.4588 - acc: 0.7771 - val_loss: 0.3798 - val_acc: 0.8077
#
# Epoch 00106: val_loss did not improve from 0.35104
# Epoch 107/1000
#  - 1s - loss: 0.3907 - acc: 0.8178 - val_loss: 0.5039 - val_acc: 0.7308
#
# Epoch 00107: val_loss did not improve from 0.35104
# Epoch 108/1000
#  - 1s - loss: 0.4502 - acc: 0.7868 - val_loss: 0.3776 - val_acc: 0.8385
#
# Epoch 00108: val_loss did not improve from 0.35104
# Epoch 109/1000
#  - 1s - loss: 0.4052 - acc: 0.8217 - val_loss: 0.4363 - val_acc: 0.7769
#
# Epoch 00109: val_loss did not improve from 0.35104
# Epoch 110/1000
#  - 1s - loss: 0.4528 - acc: 0.7888 - val_loss: 0.3639 - val_acc: 0.8385
#
# Epoch 00110: val_loss did not improve from 0.35104
# Epoch 111/1000
#  - 1s - loss: 0.4396 - acc: 0.7771 - val_loss: 0.3830 - val_acc: 0.8538
#
# Epoch 00111: val_loss did not improve from 0.35104
# Epoch 112/1000
#  - 1s - loss: 0.4249 - acc: 0.8081 - val_loss: 0.3474 - val_acc: 0.8769
#
# Epoch 00112: val_loss improved from 0.35104 to 0.34737, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 113/1000
#  - 1s - loss: 0.4173 - acc: 0.8043 - val_loss: 0.3647 - val_acc: 0.8538
#
# Epoch 00113: val_loss did not improve from 0.34737
# Epoch 114/1000
#  - 1s - loss: 0.4308 - acc: 0.8081 - val_loss: 0.3721 - val_acc: 0.8077
#
# Epoch 00114: val_loss did not improve from 0.34737
# Epoch 115/1000
#  - 1s - loss: 0.4321 - acc: 0.7965 - val_loss: 0.3541 - val_acc: 0.8462
#
# Epoch 00115: val_loss did not improve from 0.34737
# Epoch 116/1000
#  - 1s - loss: 0.4135 - acc: 0.8062 - val_loss: 0.4192 - val_acc: 0.7692
#
# Epoch 00116: val_loss did not improve from 0.34737
# Epoch 117/1000
#  - 1s - loss: 0.4521 - acc: 0.7752 - val_loss: 0.3622 - val_acc: 0.8231
#
# Epoch 00117: val_loss did not improve from 0.34737
# Epoch 118/1000
#  - 1s - loss: 0.4060 - acc: 0.8081 - val_loss: 0.4285 - val_acc: 0.8000
#
# Epoch 00118: val_loss did not improve from 0.34737
# Epoch 119/1000
#  - 1s - loss: 0.4335 - acc: 0.7984 - val_loss: 0.3884 - val_acc: 0.8231
#
# Epoch 00119: val_loss did not improve from 0.34737
# Epoch 120/1000
#  - 1s - loss: 0.4024 - acc: 0.8101 - val_loss: 0.4122 - val_acc: 0.8000
#
# Epoch 00120: val_loss did not improve from 0.34737
# Epoch 121/1000
#  - 1s - loss: 0.4189 - acc: 0.7849 - val_loss: 0.3301 - val_acc: 0.8462
#
# Epoch 00121: val_loss improved from 0.34737 to 0.33010, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 122/1000
#  - 1s - loss: 0.4182 - acc: 0.8101 - val_loss: 0.3760 - val_acc: 0.8308
#
# Epoch 00122: val_loss did not improve from 0.33010
# Epoch 123/1000
#  - 1s - loss: 0.4081 - acc: 0.8062 - val_loss: 0.4625 - val_acc: 0.8000
#
# Epoch 00123: val_loss did not improve from 0.33010
# Epoch 124/1000
#  - 1s - loss: 0.4190 - acc: 0.7946 - val_loss: 0.4912 - val_acc: 0.7692
#
# Epoch 00124: val_loss did not improve from 0.33010
# Epoch 125/1000
#  - 1s - loss: 0.4351 - acc: 0.7733 - val_loss: 0.3598 - val_acc: 0.8385
#
# Epoch 00125: val_loss did not improve from 0.33010
# Epoch 126/1000
#  - 1s - loss: 0.4192 - acc: 0.8120 - val_loss: 0.3327 - val_acc: 0.8615
#
# Epoch 00126: val_loss did not improve from 0.33010
# Epoch 127/1000
#  - 1s - loss: 0.3993 - acc: 0.8062 - val_loss: 0.3655 - val_acc: 0.8538
#
# Epoch 00127: val_loss did not improve from 0.33010
# Epoch 128/1000
#  - 1s - loss: 0.4094 - acc: 0.8043 - val_loss: 0.3379 - val_acc: 0.8615
#
# Epoch 00128: val_loss did not improve from 0.33010
# Epoch 129/1000
#  - 1s - loss: 0.4057 - acc: 0.8023 - val_loss: 0.3446 - val_acc: 0.8615
#
# Epoch 00129: val_loss did not improve from 0.33010
# Epoch 130/1000
#  - 1s - loss: 0.4265 - acc: 0.7965 - val_loss: 0.3197 - val_acc: 0.8692
#
# Epoch 00130: val_loss improved from 0.33010 to 0.31965, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 131/1000
#  - 1s - loss: 0.4051 - acc: 0.8198 - val_loss: 0.3387 - val_acc: 0.8308
#
# Epoch 00131: val_loss did not improve from 0.31965
# Epoch 132/1000
#  - 1s - loss: 0.4265 - acc: 0.8004 - val_loss: 0.3195 - val_acc: 0.8769
#
# Epoch 00132: val_loss improved from 0.31965 to 0.31953, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 133/1000
#  - 1s - loss: 0.3851 - acc: 0.8178 - val_loss: 0.3409 - val_acc: 0.8462
#
# Epoch 00133: val_loss did not improve from 0.31953
# Epoch 134/1000
#  - 1s - loss: 0.3870 - acc: 0.8295 - val_loss: 0.3340 - val_acc: 0.8538
#
# Epoch 00134: val_loss did not improve from 0.31953
# Epoch 135/1000
#  - 1s - loss: 0.3872 - acc: 0.8178 - val_loss: 0.5014 - val_acc: 0.7615
#
# Epoch 00135: val_loss did not improve from 0.31953
# Epoch 136/1000
#  - 1s - loss: 0.3827 - acc: 0.8081 - val_loss: 0.3246 - val_acc: 0.8462
#
# Epoch 00136: val_loss did not improve from 0.31953
# Epoch 137/1000
#  - 1s - loss: 0.4010 - acc: 0.7965 - val_loss: 0.3080 - val_acc: 0.8538
#
# Epoch 00137: val_loss improved from 0.31953 to 0.30801, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 138/1000
#  - 1s - loss: 0.3886 - acc: 0.8140 - val_loss: 0.4285 - val_acc: 0.8231
#
# Epoch 00138: val_loss did not improve from 0.30801
# Epoch 139/1000
#  - 1s - loss: 0.3790 - acc: 0.8353 - val_loss: 0.3283 - val_acc: 0.8538
#
# Epoch 00139: val_loss did not improve from 0.30801
# Epoch 140/1000
#  - 1s - loss: 0.3922 - acc: 0.8159 - val_loss: 0.3411 - val_acc: 0.8538
#
# Epoch 00140: val_loss did not improve from 0.30801
# Epoch 141/1000
#  - 1s - loss: 0.3895 - acc: 0.7984 - val_loss: 0.3455 - val_acc: 0.8538
#
# Epoch 00141: val_loss did not improve from 0.30801
# Epoch 142/1000
#  - 1s - loss: 0.3896 - acc: 0.8101 - val_loss: 0.4064 - val_acc: 0.8077
#
# Epoch 00142: val_loss did not improve from 0.30801
# Epoch 143/1000
#  - 1s - loss: 0.4122 - acc: 0.7829 - val_loss: 0.3120 - val_acc: 0.8538
#
# Epoch 00143: val_loss did not improve from 0.30801
# Epoch 144/1000
#  - 1s - loss: 0.3781 - acc: 0.8256 - val_loss: 0.3137 - val_acc: 0.8538
#
# Epoch 00144: val_loss did not improve from 0.30801
# Epoch 145/1000
#  - 1s - loss: 0.4051 - acc: 0.8140 - val_loss: 0.3037 - val_acc: 0.8923
#
# Epoch 00145: val_loss improved from 0.30801 to 0.30368, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 146/1000
#  - 1s - loss: 0.3544 - acc: 0.8391 - val_loss: 0.4863 - val_acc: 0.7923
#
# Epoch 00146: val_loss did not improve from 0.30368
# Epoch 147/1000
#  - 1s - loss: 0.3723 - acc: 0.8275 - val_loss: 0.2867 - val_acc: 0.8846
#
# Epoch 00147: val_loss improved from 0.30368 to 0.28667, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 148/1000
#  - 1s - loss: 0.3900 - acc: 0.8120 - val_loss: 0.3767 - val_acc: 0.8154
# Epoch 00148: val_loss did not improve from 0.28667
# Epoch 149/1000
#  - 1s - loss: 0.3724 - acc: 0.8275 - val_loss: 0.3458 - val_acc: 0.8385
#
# Epoch 00149: val_loss did not improve from 0.28667
# Epoch 150/1000
#  - 1s - loss: 0.3816 - acc: 0.8314 - val_loss: 0.3411 - val_acc: 0.8692
#
# Epoch 00150: val_loss did not improve from 0.28667
# Epoch 151/1000
#  - 1s - loss: 0.3541 - acc: 0.8391 - val_loss: 0.3068 - val_acc: 0.8692
#
# Epoch 00151: val_loss did not improve from 0.28667
# Epoch 152/1000
#  - 1s - loss: 0.3424 - acc: 0.8566 - val_loss: 0.3192 - val_acc: 0.8538
#
# Epoch 00152: val_loss did not improve from 0.28667
# Epoch 153/1000
#  - 1s - loss: 0.3812 - acc: 0.8198 - val_loss: 0.3045 - val_acc: 0.8769
#
# Epoch 00153: val_loss did not improve from 0.28667
# Epoch 154/1000
#  - 1s - loss: 0.3642 - acc: 0.8314 - val_loss: 0.2829 - val_acc: 0.8769
#
# Epoch 00154: val_loss improved from 0.28667 to 0.28290, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 155/1000
#  - 1s - loss: 0.3536 - acc: 0.8508 - val_loss: 0.4117 - val_acc: 0.8000
#
# Epoch 00155: val_loss did not improve from 0.28290
# Epoch 156/1000
#  - 1s - loss: 0.3578 - acc: 0.8314 - val_loss: 0.2969 - val_acc: 0.8769
#
# Epoch 00156: val_loss did not improve from 0.28290
# Epoch 157/1000
#  - 1s - loss: 0.3554 - acc: 0.8372 - val_loss: 0.2764 - val_acc: 0.8769
#
# Epoch 00157: val_loss improved from 0.28290 to 0.27643, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 158/1000
#  - 1s - loss: 0.3788 - acc: 0.8159 - val_loss: 0.3267 - val_acc: 0.8385
#
# Epoch 00158: val_loss did not improve from 0.27643
# Epoch 159/1000
#  - 1s - loss: 0.3528 - acc: 0.8353 - val_loss: 0.2878 - val_acc: 0.8692
#
# Epoch 00159: val_loss did not improve from 0.27643
# Epoch 160/1000
#  - 1s - loss: 0.3602 - acc: 0.8236 - val_loss: 0.3102 - val_acc: 0.8769
#
# Epoch 00160: val_loss did not improve from 0.27643
# Epoch 161/1000
#  - 1s - loss: 0.3706 - acc: 0.8275 - val_loss: 0.2750 - val_acc: 0.9000
#
# Epoch 00161: val_loss improved from 0.27643 to 0.27504, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 162/1000
#  - 1s - loss: 0.3275 - acc: 0.8760 - val_loss: 0.2974 - val_acc: 0.8615
#
# Epoch 00162: val_loss did not improve from 0.27504
# Epoch 163/1000
#  - 1s - loss: 0.3634 - acc: 0.8295 - val_loss: 0.3228 - val_acc: 0.8538
#
# Epoch 00163: val_loss did not improve from 0.27504
# Epoch 164/1000
#  - 1s - loss: 0.3593 - acc: 0.8372 - val_loss: 0.3097 - val_acc: 0.8308
#
# Epoch 00164: val_loss did not improve from 0.27504
# Epoch 165/1000
#  - 1s - loss: 0.3605 - acc: 0.8295 - val_loss: 0.2829 - val_acc: 0.8923
#
# Epoch 00165: val_loss did not improve from 0.27504
# Epoch 166/1000
#  - 1s - loss: 0.3182 - acc: 0.8663 - val_loss: 0.2795 - val_acc: 0.8769
#
# Epoch 00166: val_loss did not improve from 0.27504
# Epoch 167/1000
#  - 1s - loss: 0.3098 - acc: 0.8702 - val_loss: 0.2864 - val_acc: 0.8692
#
# Epoch 00167: val_loss did not improve from 0.27504
# Epoch 168/1000
#  - 1s - loss: 0.3264 - acc: 0.8721 - val_loss: 0.3292 - val_acc: 0.8385
#
# Epoch 00168: val_loss did not improve from 0.27504
# Epoch 169/1000
#  - 1s - loss: 0.3374 - acc: 0.8605 - val_loss: 0.3178 - val_acc: 0.8308
#
# Epoch 00169: val_loss did not improve from 0.27504
# Epoch 170/1000
#  - 1s - loss: 0.3362 - acc: 0.8391 - val_loss: 0.2740 - val_acc: 0.8846
#
# Epoch 00170: val_loss improved from 0.27504 to 0.27398, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 171/1000
#  - 1s - loss: 0.3473 - acc: 0.8314 - val_loss: 0.3651 - val_acc: 0.8385
#
# Epoch 00171: val_loss did not improve from 0.27398
# Epoch 172/1000
#  - 1s - loss: 0.3310 - acc: 0.8643 - val_loss: 0.2684 - val_acc: 0.8923
#
# Epoch 00172: val_loss improved from 0.27398 to 0.26843, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 173/1000
#  - 1s - loss: 0.3108 - acc: 0.8760 - val_loss: 0.4094 - val_acc: 0.8385
#
# Epoch 00173: val_loss did not improve from 0.26843
# Epoch 174/1000
#  - 1s - loss: 0.3347 - acc: 0.8450 - val_loss: 0.3894 - val_acc: 0.8154
#
# Epoch 00174: val_loss did not improve from 0.26843
# Epoch 175/1000
#  - 1s - loss: 0.3390 - acc: 0.8430 - val_loss: 0.3805 - val_acc: 0.8154
#
# Epoch 00175: val_loss did not improve from 0.26843
# Epoch 176/1000
#  - 1s - loss: 0.3386 - acc: 0.8469 - val_loss: 0.2615 - val_acc: 0.8923
#
# Epoch 00176: val_loss improved from 0.26843 to 0.26152, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 177/1000
#  - 1s - loss: 0.3382 - acc: 0.8314 - val_loss: 0.2801 - val_acc: 0.8769
#
# Epoch 00177: val_loss did not improve from 0.26152
# Epoch 178/1000
#  - 1s - loss: 0.2970 - acc: 0.8740 - val_loss: 0.2645 - val_acc: 0.8846
#
# Epoch 00178: val_loss did not improve from 0.26152
# Epoch 179/1000
#  - 1s - loss: 0.3229 - acc: 0.8527 - val_loss: 0.2855 - val_acc: 0.8692
#
# Epoch 00179: val_loss did not improve from 0.26152
# Epoch 180/1000
#  - 1s - loss: 0.3207 - acc: 0.8547 - val_loss: 0.2752 - val_acc: 0.8769
#
# Epoch 00180: val_loss did not improve from 0.26152
# Epoch 181/1000
#  - 1s - loss: 0.3345 - acc: 0.8488 - val_loss: 0.2757 - val_acc: 0.8769
#
# Epoch 00181: val_loss did not improve from 0.26152
# Epoch 182/1000
#  - 1s - loss: 0.2936 - acc: 0.8798 - val_loss: 0.3197 - val_acc: 0.8385
#
# Epoch 00182: val_loss did not improve from 0.26152
# Epoch 183/1000
#  - 1s - loss: 0.3170 - acc: 0.8643 - val_loss: 0.3255 - val_acc: 0.8154
#
# Epoch 00183: val_loss did not improve from 0.26152
# Epoch 184/1000
#  - 1s - loss: 0.3098 - acc: 0.8566 - val_loss: 0.3150 - val_acc: 0.8615
#
# Epoch 00184: val_loss did not improve from 0.26152
# Epoch 185/1000
#  - 1s - loss: 0.2968 - acc: 0.8585 - val_loss: 0.2586 - val_acc: 0.8923
#
# Epoch 00185: val_loss improved from 0.26152 to 0.25865, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 186/1000
#  - 1s - loss: 0.3371 - acc: 0.8508 - val_loss: 0.2641 - val_acc: 0.8846
#
# Epoch 00186: val_loss did not improve from 0.25865
# Epoch 187/1000
#  - 1s - loss: 0.2875 - acc: 0.8760 - val_loss: 0.2441 - val_acc: 0.8846
#
# Epoch 00187: val_loss improved from 0.25865 to 0.24413, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 188/1000
#  - 1s - loss: 0.3427 - acc: 0.8488 - val_loss: 0.2736 - val_acc: 0.8692
#
# Epoch 00188: val_loss did not improve from 0.24413
# Epoch 189/1000
#  - 1s - loss: 0.2890 - acc: 0.8895 - val_loss: 0.2731 - val_acc: 0.8462
#
# Epoch 00189: val_loss did not improve from 0.24413
# Epoch 190/1000
#  - 1s - loss: 0.3049 - acc: 0.8643 - val_loss: 0.3447 - val_acc: 0.8462
#
# Epoch 00190: val_loss did not improve from 0.24413
# Epoch 191/1000
#  - 1s - loss: 0.2916 - acc: 0.8721 - val_loss: 0.2999 - val_acc: 0.8692
#
# Epoch 00191: val_loss did not improve from 0.24413
# Epoch 192/1000
#  - 1s - loss: 0.2965 - acc: 0.8779 - val_loss: 0.3753 - val_acc: 0.8385
#
# Epoch 00192: val_loss did not improve from 0.24413
# Epoch 193/1000
#  - 1s - loss: 0.2854 - acc: 0.8915 - val_loss: 0.4634 - val_acc: 0.7385
#
# Epoch 00193: val_loss did not improve from 0.24413
# Epoch 194/1000
#  - 1s - loss: 0.3203 - acc: 0.8663 - val_loss: 0.3465 - val_acc: 0.8615
#
# Epoch 00194: val_loss did not improve from 0.24413
# Epoch 195/1000
#  - 1s - loss: 0.2842 - acc: 0.8876 - val_loss: 0.2871 - val_acc: 0.8615
#
# Epoch 00195: val_loss did not improve from 0.24413
# Epoch 196/1000
#  - 1s - loss: 0.3119 - acc: 0.8682 - val_loss: 0.2733 - val_acc: 0.8538
#
# Epoch 00196: val_loss did not improve from 0.24413
# Epoch 197/1000
#  - 1s - loss: 0.3244 - acc: 0.8469 - val_loss: 0.2771 - val_acc: 0.8769
#
# Epoch 00197: val_loss did not improve from 0.24413

# %%
model_2 = Sequential()
model_2.add(Conv2D(input_shape=(224,224,3), filters=16, kernel_size=(5,5), padding='same', activation='relu', strides=1))
model_2.add(MaxPooling2D(pool_size=(3,3)))
model_2.add(BatchNormalization())
model_2.add(Conv2D(input_shape=train_tensors.shape, filters=32, kernel_size=(4,4), padding='same', activation='relu', strides=1))
model_2.add(MaxPooling2D(pool_size=(2,2)))
model_2.add(BatchNormalization())
model_2.add(Conv2D(input_shape=train_tensors.shape, filters=64, kernel_size=(3,3), padding='same', activation='relu'))
model_2.add(MaxPooling2D(pool_size=(2,2), strides=1))
model_2.add(BatchNormalization())
model_2.add(Conv2D(input_shape=(224,224,3), filters=128, kernel_size=(3,3), padding='same', activation='relu'))
model_2.add(MaxPooling2D(pool_size=(2,2), strides=1))
model_2.add(BatchNormalization())
model_2.add(Conv2D(input_shape=(224,224,3), filters=256, kernel_size=(3,3), padding='same', activation='relu'))
model_2.add(MaxPooling2D(pool_size=(2,2), strides=1))
model_2.add(BatchNormalization())
model_2.add(Conv2D(input_shape=(224,224,3), filters=512, kernel_size=(3,3), padding='same', activation='relu'))
model_2.add(MaxPooling2D(pool_size=(2,2), strides=1))
model_2.add(BatchNormalization())
model_2.add(Conv2D(input_shape=(224,224,3), filters=1024, kernel_size=(3,3), padding='same', activation='relu'))
model_2.add(MaxPooling2D(pool_size=(2,2), strides=1))
model_2.add(BatchNormalization())
model_2.add(GlobalAveragePooling2D(data_format=None))
model_2.add(Dense(2, activation = 'softmax'))

model_2.summary()
model_compile_fit(model_2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_35 (Conv2D)           (None, 224, 224, 16)      1216
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 74, 74, 16)        0
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 74, 74, 16)        64
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 74, 74, 32)        8224
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 37, 37, 32)        0
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 37, 37, 32)        128
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 37, 37, 64)        18496
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 36, 36, 64)        0
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 36, 36, 64)        256
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 36, 36, 128)       73856
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 35, 35, 128)       0
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 35, 35, 128)       512
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 35, 35, 256)       295168
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 34, 34, 256)       0
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 34, 34, 256)       1024
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 34, 34, 512)       1180160
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 33, 33, 512)       0
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 33, 33, 512)       2048
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 33, 33, 1024)      4719616
# _________________________________________________________________
# max_pooling2d_41 (MaxPooling (None, 32, 32, 1024)      0
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 32, 32, 1024)      4096
# _________________________________________________________________
# global_average_pooling2d_6 ( (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 6,306,914
# Trainable params: 6,302,850
# Non-trainable params: 4,064
# _________________________________________________________________
# Optimizer: rmsprop
# Patience: 10
# Train on 516 samples, validate on 130 samples
# Epoch 1/1000
#  - 8s - loss: 1.7794 - acc: 0.6395 - val_loss: 1.5844 - val_acc: 0.6077
#
# Epoch 00001: val_loss improved from inf to 1.58444, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 2/1000
#  - 4s - loss: 0.5598 - acc: 0.7132 - val_loss: 3.4774 - val_acc: 0.4231
#
# Epoch 00002: val_loss did not improve from 1.58444
# Epoch 3/1000
#  - 4s - loss: 0.5500 - acc: 0.7558 - val_loss: 0.5557 - val_acc: 0.7692
#
# Epoch 00003: val_loss improved from 1.58444 to 0.55572, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 4/1000
#  - 4s - loss: 0.4479 - acc: 0.7907 - val_loss: 6.9010 - val_acc: 0.4231
#
# Epoch 00004: val_loss did not improve from 0.55572
# Epoch 5/1000
#  - 4s - loss: 0.3806 - acc: 0.8295 - val_loss: 9.2989 - val_acc: 0.4231
#
# Epoch 00005: val_loss did not improve from 0.55572
# Epoch 6/1000
#  - 4s - loss: 0.3088 - acc: 0.8605 - val_loss: 3.4476 - val_acc: 0.5385
#
# Epoch 00006: val_loss did not improve from 0.55572
# Epoch 7/1000
#  - 4s - loss: 0.2837 - acc: 0.8953 - val_loss: 9.2901 - val_acc: 0.4231
#
# Epoch 00007: val_loss did not improve from 0.55572
# Epoch 8/1000
#  - 4s - loss: 0.1995 - acc: 0.9186 - val_loss: 0.1913 - val_acc: 0.9308
#
# Epoch 00008: val_loss improved from 0.55572 to 0.19133, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 9/1000
#  - 4s - loss: 0.1670 - acc: 0.9360 - val_loss: 1.3121 - val_acc: 0.7308
#
# Epoch 00009: val_loss did not improve from 0.19133
# Epoch 10/1000
#  - 4s - loss: 0.1684 - acc: 0.9322 - val_loss: 9.2989 - val_acc: 0.4231
#
# Epoch 00010: val_loss did not improve from 0.19133
# Epoch 11/1000
#  - 4s - loss: 0.1868 - acc: 0.9399 - val_loss: 4.4622 - val_acc: 0.5000
#
# Epoch 00011: val_loss did not improve from 0.19133
# Epoch 12/1000
#  - 4s - loss: 0.1441 - acc: 0.9477 - val_loss: 8.2824 - val_acc: 0.4462
#
# Epoch 00012: val_loss did not improve from 0.19133
# Epoch 13/1000
#  - 4s - loss: 0.0976 - acc: 0.9709 - val_loss: 3.1049 - val_acc: 0.4538
#
# Epoch 00013: val_loss did not improve from 0.19133
# Epoch 14/1000
#  - 4s - loss: 0.1178 - acc: 0.9535 - val_loss: 0.1294 - val_acc: 0.9615
#
# Epoch 00014: val_loss improved from 0.19133 to 0.12940, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 15/1000
#  - 4s - loss: 0.0865 - acc: 0.9709 - val_loss: 7.9850 - val_acc: 0.4231
#
# Epoch 00015: val_loss did not improve from 0.12940
# Epoch 16/1000
#  - 4s - loss: 0.0714 - acc: 0.9826 - val_loss: 9.2850 - val_acc: 0.4231
#
# Epoch 00016: val_loss did not improve from 0.12940
# Epoch 17/1000
#  - 4s - loss: 0.0841 - acc: 0.9729 - val_loss: 0.3925 - val_acc: 0.8923
#
# Epoch 00017: val_loss did not improve from 0.12940
# Epoch 18/1000
#  - 4s - loss: 0.0575 - acc: 0.9767 - val_loss: 4.6746 - val_acc: 0.4769
#
# Epoch 00018: val_loss did not improve from 0.12940
# Epoch 19/1000
#  - 4s - loss: 0.0556 - acc: 0.9806 - val_loss: 2.3168 - val_acc: 0.6077
#
# Epoch 00019: val_loss did not improve from 0.12940
# Epoch 20/1000
#  - 4s - loss: 0.0082 - acc: 0.9981 - val_loss: 0.5694 - val_acc: 0.8692
#
# Epoch 00020: val_loss did not improve from 0.12940
# Epoch 21/1000
#  - 4s - loss: 0.0951 - acc: 0.9729 - val_loss: 5.6380 - val_acc: 0.4846
#
# Epoch 00021: val_loss did not improve from 0.12940
# Epoch 22/1000
#  - 4s - loss: 0.0471 - acc: 0.9845 - val_loss: 2.7375 - val_acc: 0.5615
#
# Epoch 00022: val_loss did not improve from 0.12940
# Epoch 23/1000
#  - 4s - loss: 0.0436 - acc: 0.9845 - val_loss: 3.0904 - val_acc: 0.6154
#
# Epoch 00023: val_loss did not improve from 0.12940
# Epoch 24/1000
#  - 4s - loss: 0.0657 - acc: 0.9709 - val_loss: 1.5602 - val_acc: 0.8231
#
# Epoch 00024: val_loss did not improve from 0.12940

# %%
def augmented_data_model_compile_fit(model):
    
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    print("Optimizer:", optimizer)
    print("Patience:", patience)
    
    checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)
    
    early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=patience, verbose=0, mode='auto', 
          baseline=None, restore_best_weights=False)
    
    #Create and configure augmented image generator

    datagen =ImageDataGenerator(width_shift_range=0.1, # randomly shift images horizontally (10% of total width)
                                height_shift_range=0.1, # randomly shift images vertically (10% of total height)
                                zoom_range=0.2) # range for random zoom) 
    
    #fit augmented image generator on data
    datagen.fit(train_tensors)
    
    batch_size = 20
    
    # train the model
    model.fit_generator(datagen.flow(train_tensors, train_targets, batch_size=batch_size),
                          steps_per_epoch=3*(train_tensors.shape[0]//batch_size),
                          epochs=epochs, verbose=2, callbacks=[checkpointer, early_stopping],
                         validation_data=(valid_tensors, valid_targets))
    
    # load the weights that generated the best validation accuracy
    model.load_weights('saved_models/weights.best.from_scratch.hdf5')
       
    # get index of predicted action for each image in test set
    action_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

    # report test accuracy
    test_accuracy = 100*np.sum(np.array(action_predictions)==np.argmax(test_targets, axis=1))/len(action_predictions) 
    print('Test accuracy: %.4f%%' % test_accuracy)

# %%
rmsprop_lowLR = optimizers.RMSprop(lr=0.0001)
optimizer= rmsprop_lowLR
patience= 15

aug_model9 = Sequential()
aug_model9.add(Conv2D(input_shape=(224,224,3), filters=16, kernel_size=(5,5), padding='same', activation='relu', strides=1))
aug_model9.add(MaxPooling2D(pool_size=(3,3)))
aug_model9.add(BatchNormalization())
aug_model9.add(Conv2D(input_shape=train_tensors.shape, filters=32, kernel_size=(4,4), padding='same', activation='relu', strides=1))
aug_model9.add(MaxPooling2D(pool_size=(2,2)))
aug_model9.add(BatchNormalization())
aug_model9.add(Conv2D(input_shape=train_tensors.shape, filters=64, kernel_size=(3,3), padding='same', activation='relu'))
aug_model9.add(MaxPooling2D(pool_size=(2,2), strides=1))
aug_model9.add(BatchNormalization())
aug_model9.add(Conv2D(input_shape=(224,224,3), filters=128, kernel_size=(3,3), padding='same', activation='relu'))
aug_model9.add(MaxPooling2D(pool_size=(2,2), strides=1))
aug_model9.add(BatchNormalization())
aug_model9.add(Conv2D(input_shape=(224,224,3), filters=256, kernel_size=(3,3), padding='same', activation='relu'))
aug_model9.add(MaxPooling2D(pool_size=(2,2), strides=1))
aug_model9.add(BatchNormalization())
aug_model9.add(Conv2D(input_shape=(224,224,3), filters=512, kernel_size=(3,3), padding='same', activation='relu'))
aug_model9.add(MaxPooling2D(pool_size=(2,2), strides=1))
aug_model9.add(BatchNormalization())
aug_model9.add(Conv2D(input_shape=(224,224,3), filters=1024, kernel_size=(3,3), padding='same', activation='relu'))
aug_model9.add(MaxPooling2D(pool_size=(2,2), strides=1))
aug_model9.add(BatchNormalization())
aug_model9.add(GlobalAveragePooling2D(data_format=None))
aug_model9.add(Dense(2, activation = 'softmax'))

aug_model9.summary()
augmented_data_model_compile_fit(aug_model9)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 224, 224, 16)      1216
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 74, 74, 16)        0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 74, 74, 16)        64
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 74, 74, 32)        8224
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 37, 37, 32)        0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 37, 37, 32)        128
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 37, 37, 64)        18496
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 36, 36, 64)        0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 36, 36, 64)        256
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 36, 36, 128)       73856
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 35, 35, 128)       0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 35, 35, 128)       512
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 35, 35, 256)       295168
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 34, 34, 256)       0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 34, 34, 256)       1024
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 34, 34, 512)       1180160
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 33, 33, 512)       0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 33, 33, 512)       2048
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 33, 33, 1024)      4719616
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 32, 32, 1024)      0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 32, 32, 1024)      4096
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 6,306,914
# Trainable params: 6,302,850
# Non-trainable params: 4,064
# _________________________________________________________________
# Optimizer: <keras.optimizers.RMSprop object at 0x00000172F653D828>
# Patience: 15
# Epoch 1/1000
#  - 12s - loss: 0.7431 - acc: 0.7185 - val_loss: 0.5183 - val_acc: 0.8231
#
# Epoch 00001: val_loss improved from inf to 0.51826, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 2/1000
#  - 11s - loss: 0.3357 - acc: 0.8562 - val_loss: 1.4397 - val_acc: 0.7154
#
# Epoch 00002: val_loss did not improve from 0.51826
# Epoch 3/1000
#  - 11s - loss: 0.2780 - acc: 0.8815 - val_loss: 0.8083 - val_acc: 0.7769
#
# Epoch 00003: val_loss did not improve from 0.51826
# Epoch 4/1000
#  - 11s - loss: 0.1817 - acc: 0.9295 - val_loss: 0.1948 - val_acc: 0.9077
#
# Epoch 00004: val_loss improved from 0.51826 to 0.19475, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 5/1000
#  - 11s - loss: 0.1416 - acc: 0.9402 - val_loss: 0.1568 - val_acc: 0.9308
#
# Epoch 00005: val_loss improved from 0.19475 to 0.15682, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 6/1000
#  - 11s - loss: 0.0928 - acc: 0.9643 - val_loss: 0.4648 - val_acc: 0.8538
#
# Epoch 00006: val_loss did not improve from 0.15682
# Epoch 7/1000
#  - 11s - loss: 0.0962 - acc: 0.9665 - val_loss: 0.1452 - val_acc: 0.9385
#
# Epoch 00007: val_loss improved from 0.15682 to 0.14524, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 8/1000
#  - 11s - loss: 0.0846 - acc: 0.9655 - val_loss: 0.5011 - val_acc: 0.8308
#
# Epoch 00008: val_loss did not improve from 0.14524
# Epoch 9/1000
#  - 11s - loss: 0.0921 - acc: 0.9667 - val_loss: 0.0413 - val_acc: 0.9692
#
# Epoch 00009: val_loss improved from 0.14524 to 0.04133, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 10/1000
#  - 11s - loss: 0.0710 - acc: 0.9732 - val_loss: 0.1318 - val_acc: 0.9538
#
# Epoch 00010: val_loss did not improve from 0.04133
# Epoch 11/1000
#  - 11s - loss: 0.0564 - acc: 0.9783 - val_loss: 0.4935 - val_acc: 0.8308
#
# Epoch 00011: val_loss did not improve from 0.04133
# Epoch 12/1000
#  - 11s - loss: 0.0347 - acc: 0.9893 - val_loss: 0.3289 - val_acc: 0.9154
#
# Epoch 00012: val_loss did not improve from 0.04133
# Epoch 13/1000
#  - 11s - loss: 0.0492 - acc: 0.9837 - val_loss: 0.1357 - val_acc: 0.9308
#
# Epoch 00013: val_loss did not improve from 0.04133
# Epoch 14/1000
#  - 11s - loss: 0.0532 - acc: 0.9825 - val_loss: 0.2812 - val_acc: 0.8923
#
# Epoch 00014: val_loss did not improve from 0.04133
# Epoch 15/1000
#  - 11s - loss: 0.0535 - acc: 0.9828 - val_loss: 0.2053 - val_acc: 0.9615
#
# Epoch 00015: val_loss did not improve from 0.04133
# Epoch 16/1000
#  - 11s - loss: 0.0324 - acc: 0.9907 - val_loss: 0.2978 - val_acc: 0.8923
#
# Epoch 00016: val_loss did not improve from 0.04133
# Epoch 17/1000
#  - 11s - loss: 0.0315 - acc: 0.9900 - val_loss: 0.0677 - val_acc: 0.9769
#
# Epoch 00017: val_loss did not improve from 0.04133
# Epoch 18/1000
#  - 11s - loss: 0.0383 - acc: 0.9832 - val_loss: 0.0841 - val_acc: 0.9538
#
# Epoch 00018: val_loss did not improve from 0.04133
# Epoch 19/1000
#  - 11s - loss: 0.0258 - acc: 0.9912 - val_loss: 0.2841 - val_acc: 0.9308
#
# Epoch 00019: val_loss did not improve from 0.04133
# Epoch 20/1000
#  - 11s - loss: 0.0415 - acc: 0.9865 - val_loss: 0.0108 - val_acc: 1.0000
#
# Epoch 00020: val_loss improved from 0.04133 to 0.01081, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 21/1000
#  - 11s - loss: 0.0416 - acc: 0.9880 - val_loss: 0.0296 - val_acc: 0.9923
#
# Epoch 00021: val_loss did not improve from 0.01081
# Epoch 22/1000
#  - 11s - loss: 0.0286 - acc: 0.9905 - val_loss: 0.0223 - val_acc: 0.9923
#
# Epoch 00022: val_loss did not improve from 0.01081
# Epoch 23/1000
#  - 11s - loss: 0.0275 - acc: 0.9923 - val_loss: 0.0054 - val_acc: 1.0000
#
# Epoch 00023: val_loss improved from 0.01081 to 0.00541, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 24/1000
#  - 11s - loss: 0.0218 - acc: 0.9920 - val_loss: 0.2273 - val_acc: 0.9308
#
# Epoch 00024: val_loss did not improve from 0.00541
# Epoch 25/1000
#  - 11s - loss: 0.0217 - acc: 0.9940 - val_loss: 0.0977 - val_acc: 0.9692
#
# Epoch 00025: val_loss did not improve from 0.00541
# Epoch 26/1000
#  - 11s - loss: 0.0189 - acc: 0.9933 - val_loss: 0.0038 - val_acc: 1.0000
#
# Epoch 00026: val_loss improved from 0.00541 to 0.00376, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 27/1000
#  - 11s - loss: 0.0086 - acc: 0.9987 - val_loss: 0.0050 - val_acc: 1.0000
#
# Epoch 00027: val_loss did not improve from 0.00376
# Epoch 28/1000
#  - 11s - loss: 0.0137 - acc: 0.9953 - val_loss: 0.0026 - val_acc: 1.0000
#
# Epoch 00028: val_loss improved from 0.00376 to 0.00261, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 29/1000
#  - 11s - loss: 0.0194 - acc: 0.9932 - val_loss: 0.8006 - val_acc: 0.8846
#
# Epoch 00029: val_loss did not improve from 0.00261
# Epoch 30/1000
#  - 11s - loss: 0.0390 - acc: 0.9873 - val_loss: 0.0186 - val_acc: 0.9923
# Epoch 00030: val_loss did not improve from 0.00261
# Epoch 31/1000
#  - 11s - loss: 0.0149 - acc: 0.9958 - val_loss: 0.0238 - val_acc: 0.9846
#
# Epoch 00031: val_loss did not improve from 0.00261
# Epoch 32/1000
#  - 11s - loss: 0.0139 - acc: 0.9945 - val_loss: 0.0435 - val_acc: 0.9846
#
# Epoch 00032: val_loss did not improve from 0.00261
# Epoch 33/1000
#  - 11s - loss: 0.0144 - acc: 0.9967 - val_loss: 0.0180 - val_acc: 1.0000
#
# Epoch 00033: val_loss did not improve from 0.00261
# Epoch 34/1000
#  - 11s - loss: 0.0160 - acc: 0.9938 - val_loss: 0.2050 - val_acc: 0.9538
#
# Epoch 00034: val_loss did not improve from 0.00261
# Epoch 35/1000
#  - 11s - loss: 0.0078 - acc: 0.9973 - val_loss: 0.2848 - val_acc: 0.9154
#
# Epoch 00035: val_loss did not improve from 0.00261
# Epoch 36/1000
#  - 11s - loss: 0.0213 - acc: 0.9967 - val_loss: 0.2697 - val_acc: 0.8923
#
# Epoch 00036: val_loss did not improve from 0.00261
# Epoch 37/1000
#  - 11s - loss: 0.0180 - acc: 0.9960 - val_loss: 0.0220 - val_acc: 0.9923
#
# Epoch 00037: val_loss did not improve from 0.00261
# Epoch 38/1000
#  - 11s - loss: 0.0103 - acc: 0.9973 - val_loss: 0.0278 - val_acc: 0.9846
#
# Epoch 00038: val_loss did not improve from 0.00261
# Epoch 39/1000
#  - 11s - loss: 0.0208 - acc: 0.9923 - val_loss: 0.4772 - val_acc: 0.9000
#
# Epoch 00039: val_loss did not improve from 0.00261
# Epoch 40/1000
#  - 11s - loss: 0.0146 - acc: 0.9973 - val_loss: 0.0227 - val_acc: 0.9846
#
# Epoch 00040: val_loss did not improve from 0.00261
# Epoch 41/1000
#  - 11s - loss: 0.0141 - acc: 0.9947 - val_loss: 0.0059 - val_acc: 1.0000
#
# Epoch 00041: val_loss did not improve from 0.00261
# Epoch 42/1000
#  - 11s - loss: 0.0048 - acc: 0.9987 - val_loss: 0.0925 - val_acc: 0.9769
#
# Epoch 00042: val_loss did not improve from 0.00261
# Epoch 43/1000
#  - 11s - loss: 0.0141 - acc: 0.9953 - val_loss: 0.0169 - val_acc: 0.9923
#
# Epoch 00043: val_loss did not improve from 0.00261
# Test accuracy: 2750.0000%

# %%
# load the weights that generated the best validation accuracy
aug_model9.load_weights('saved_models/weights.best.from_scratch.hdf5')
       
# get index of predicted action for each image in test set
action_predictions = [np.argmax(aug_model9.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(action_predictions)==np.argmax(test_targets, axis=1))/len(action_predictions) 
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 72.3684%

# %%
#Acquire the bottleneck features from Resnet-50
bottleneck_features = np.load('resnet50_features/DogResnet50Data.npz')
train_Resnet50 = bottleneck_features['train']
valid_Resnet50 = bottleneck_features['valid']
test_Resnet50 = bottleneck_features['test']

# %%
#Create the model architecture
Resnet50_model = Sequential()
Resnet50_model.add(GlobalAveragePooling2D(input_shape=train_Resnet50.shape[1:]))
Resnet50_model.add(Dense(133, activation='relu'))
Resnet50_model.add(Dense(2, activation='softmax'))

Resnet50_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_4 ( (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 133)               272517
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 268
# =================================================================
# Total params: 272,785
# Trainable params: 272,785
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_compile_fit(Resnet50_model)
# Out:
# Optimizer: <keras.optimizers.RMSprop object at 0x00000172F653D828>
# Patience: 15
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-bee513a7940f> in <module>
# ----> 1 model_compile_fit(Resnet50_model)
#
# <ipython-input-6-e7011866892f> in model_compile_fit(model)
#      14           validation_data=(valid_tensors, valid_targets),
#      15           epochs=epochs, batch_size=20, callbacks=[checkpointer,
# ---> 16           early_stopping], verbose=2)
#      17
#      18     model.load_weights('saved_models/weights.best.from_scratch.hdf5')
#
# ~\AppData\Local\conda\conda\envs\deeplearning\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     950             sample_weight=sample_weight,
#     951             class_weight=class_weight,
# --> 952             batch_size=batch_size)
#     953         # Prepare validation data.
#     954         do_validation = False
#
# ~\AppData\Local\conda\conda\envs\deeplearning\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     749             feed_input_shapes,
#     750             check_batch_axis=False,  # Don't enforce the batch size.
# --> 751             exception_prefix='input')
#     752
#     753         if y is not None:
#
# ~\AppData\Local\conda\conda\envs\deeplearning\lib\site-packages\keras\engine\training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     136                             ': expected ' + names[i] + ' to have shape ' +
#     137                             str(shape) + ' but got array with shape ' +
# --> 138                             str(data_shape))
#     139     return data
#     140
#
# ValueError: Error when checking input: expected global_average_pooling2d_4_input to have shape (1, 1, 2048) but got array with shape (224, 224, 3)
